# %%
import logging

# %%
## Configure the basic logging settings
logging.basicConfig(level=logging.DEBUG)

## log messages with different severity levels
logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")
# Out:
# DEBUG:root:This is a debug message
# INFO:root:This is an info message
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %%
logging.debug("jai shree ram , mera namm manoj singh rawat hai , mein uttarakhand se hun")
# Out:
# DEBUG:root:jai shree ram , mera namm manoj singh rawat hai , mein uttarakhand se hun

# %%
# Create a formatter for the log messages
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# Use the formatter for the file handler
file_handler.setFormatter(formatter)

# Create a custom logger
custom_logger = logging.getLogger('custom_logger')

# Add the file handler to the custom logger
custom_logger.addHandler(file_handler)

# Log messages to test the file handler
custom_logger.error("This error will be logged in the file")
custom_logger.critical("This critical error will also be logged in the file")
# Out:
# ERROR:custom_logger:This error will be logged in the file
# CRITICAL:custom_logger:This critical error will also be logged in the file
